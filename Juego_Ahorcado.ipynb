# %% [markdown]
# <a href="https://colab.research.google.com/github/cate1285/Games/blob/main/Juego_Ahorcado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# El Ahorcado es un juego para dos personas, usualmente jugado con lápiz y papel. Un jugador
# piensa en una palabra y dibuja un espacio en la página por cada letra de la palabra. Entonces el
# segundo jugador intenta adivinar letras de la palabra.
# Si adivina correctamente, el primer jugador escribe la letra en el espacio correspondiente. Si la
# letra no está en la palabra, el primer jugador dibuja una parte del cuerpo del ahorcado. Si el
# segundo jugador consigue adivinar todas las letras de la palabra antes de que el dibujo del
# ahorcado esté completo, gana. ¡Pero si no consigue adivinar la palabra a tiempo el segundo
# jugador pierde!

# %%
import random 
imagenes=["""
+---+
 | |
 |
 |
 |
 |
=========""",'''
+---+
 | |
 O |
 |
 |
 |
=========''', '''
+---+
 | |
 O |
 | |
 |
 |
=========''', '''
+---+
 | |
 O |
/| |
 |
 |
=========''', '''
 +---+
 | |
 O |
/|\ |
 |
 |
=========''', '''
+---+
 | |
 O |
/|\ |
/  |
 |
 =========''', '''
+---+
 | |
 O |
/|\ |
/ \ |
 |
=========''']

words_rando=["cang", "perro", "gato", "caba"]
def word_selected(words_rando):
  words_rando=random.choice(words_rando)
  return  words_rando
word_selected(words_rando)

def tablero (imagenes,letras_incorrectas,elected_word,letras_correctas):
  print(imagenes [len(letras_incorrectas)])
  print()

  print("letras incorrectas:", end=" ")
  for i in letras_incorrectas:
    print(i,end="")
  print()

  espacios_vacios="_" * len(elected_word)

  for i in range(len(elected_word)):
    if elected_word[i] in letras_correctas:
      espacios_vacios= espacios_vacios[:i] + elected_word[i] + espacios_vacios[i+1:]
  for x in espacios_vacios:
    print(x, end="")
  print()

def customer_letter(letras_probadas):
  while True:
    print("Ingrese una letra")
    letter=input()
    letter=letter.lower()
    if len(letter) !=1:
      print("ingresa solo una letra")
    elif letter in letras_probadas:
      print("ya la probaste")
    elif letter not in "abcdefghijklmnñopuqrvstxyz":
      print("tiene que se una letra")
    else:
      return letter

def jugar_n():
  print("Quieres jugar nuevamente")
  return input().lower().startswith("s")
  
 
elected_word= word_selected(words_rando)
letras_incorrectas=""
letras_correctas= ""
juego_terminado=False

while True:
  tablero (imagenes,letras_incorrectas,elected_word,letras_correctas)
  letter = customer_letter(letras_incorrectas+letras_correctas)
  if letter in elected_word:
    letras_correctas=letras_correctas + letter
    encontrado_letras=True
    for i in range(len(elected_word)):
      if elected_word[i] not in letras_correctas:
        encontrado_letras=False
        break
    if encontrado_letras:
      print("has ganado, la palabra era "+elected_word)
      juego_terminado=True
  
  else:
    letras_incorrectas= letras_incorrectas + letter
    if len(letras_incorrectas)==len(imagenes)-1:
      tablero (imagenes,letras_incorrectas,elected_word,letras_correctas)
      print("perdiste")
      juego_terminado=True

  if juego_terminado:
    if jugar_n():
      letras_incorrectas=""
      letras_correctas=""
      elected_word=word_selected(words_rando)
      juego_terminado=False
    else:
      break

# %%
import random 
imagenes=["""
+---+
 | |
 |
 |
 |
 |
=========""",'''
+---+
 | |
 O |
 |
 |
 |
=========''', '''
+---+
 | |
 O |
 | |
 |
 |
=========''', '''
+---+
 | |
 O |
/| |
 |
 |
=========''', '''
 +---+
 | |
 O |
/|\ |
 |
 |
=========''', '''
+---+
 | |
 O |
/|\ |
/  |
 |
 =========''', '''
+---+
 | |
 O |
/|\ |
/ \ |
 |
=========''']

words_rando=["cangrejo", "perro", "gato", "caballo"]
def word_selected(words_rando):
  words_rando=random.choice(words_rando)
  return  words_rando
word_selected(words_rando)

def tablero(imagenes,letrasincorrectas,palabra,letrascorrectas):
  
  print(imagenes[len(letrasincorrectas)])
  print()
  
  print("letras incorrectas:",end=" ")
  for i in letrasincorrectas:
    print(i,end="")
  print()

  espaciosvacios= "_"*len(palabra)
  print("letras correctas")
  for x in range(len(palabra)):
    if palabra[x] in letrascorrectas:
      espaciosvacios=espaciosvacios[:x] + palabra[x]+ espaciosvacios[x+1:]  
  for m in espaciosvacios:
    print(m,end="")
  print()

def prueba(letrasprobadas):
  letra=input("ingresa una letra")
  if len(letra) !=1:
    print("solo puedes ingresar una letra")
  elif letra not in "abcdefghijklmnopqrstuvwxyz":
    print("debe ser una letra")
  else:
    return letra
def jugarotra():
  print("Jugar otra vez?")
  return input().lower().startswith("s")

letrasincorrectas=""
palabra=word_selected(words_rando)
letrascorrectas=""
juegoterminado=False

while True:
  tablero(imagenes,letrasincorrectas,palabra,letrascorrectas)
  letra=prueba(letrasincorrectas+letrascorrectas)
  if letra in palabra:
    letrascorrectas=letrascorrectas+letra
    secumple=True
    for i in range(len(palabra)):
      if palabra[i]not in letrascorrectas:
        secumple=False
        break
    if secumple:
      print("gano")
      juegoterminado=True
  else:
    letrasincorrectas=letrasincorrectas+letra
    if len(letrasincorrectas)==len(imagenes)-1:
      print("no hay intentos")
      juegoterminado=True

  if juegoterminado:
    if jugarotra():
      letrasincorrectas=""
      palabra=word_selected(words_rando)
      letrascorrectas=""
      juegoterminado=False
    else:
      break
